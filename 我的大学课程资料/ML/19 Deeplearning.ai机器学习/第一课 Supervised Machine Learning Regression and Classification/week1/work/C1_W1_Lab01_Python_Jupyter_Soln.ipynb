# %% [markdown]
# # 可选实验：Python 和 Jupyter Notebooks 简介
# 欢迎来到第一个可选实验！
# 可选实验的目的是：
# - 提供信息 - 如这个笔记本
# - 通过动手实例加强课程材料
# - 为评分实验中使用的例程提供工作示例

# %% [markdown]
# ## 目标
# 在这个实验中，您将：
# - 获得 Jupyter notebooks 的简要介绍
# - 浏览 Jupyter notebooks
# - 学习 markdown 单元格和代码单元格的区别
# - 练习一些基本的 Python

# %% [markdown]
# 熟悉 Jupyter notebooks 最简单的方法是参加上方帮助菜单中的教程：

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Jupyter notebooks 有两种在本课程中使用的单元格类型。像这样包含文档的单元格称为 `Markdown 单元格`。这个名称来源于单元格中使用的简单格式化语言。您不需要创建 markdown 单元格。理解下图所示的 `单元格下拉菜单` 是很有用的。有时，单元格可能会处于错误的模式，您可能需要将其恢复到正确的状态：

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 另一种单元格类型是 `代码单元格`，您将在其中编写代码：

# %%
# 这是一个'代码'单元格
print("这是代码单元格")
# Out:
# This is  code cell

# %% [markdown]
# ## Python
# 您可以在代码单元格中编写代码。
# 要运行代码，选择单元格并：
# - 按住 shift 键并点击 'enter' 或 'return'
# - 点击上方的'运行'箭头
# <figure>
#     <img src="./images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### Print 语句
# Print 语句通常使用 Python f-string 样式。
# 尝试在下面的单元格中创建您自己的 print 语句。
# 尝试两种运行单元格的方法。

# %%
# print 语句
variable = "直接在字符串中！"
print(f"f 字符串允许您嵌入变量 {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # 恭喜！
# 您现在知道如何使用 Jupyter Notebook 了。
